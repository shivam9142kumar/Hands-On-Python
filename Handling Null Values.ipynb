# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Use raw string to avoid issues with backslashes in the file path
df = pd.read_csv(r"C:\Users\Shivam Kumar\Desktop\Practice{2}.csv")
df.head()
# Out:
#    Unnamed: 0 Customer ID              Name Gender  Age  Income (USD)  \
# 0           0     C-26247  Tandra Olszewski      F   47       3472.69
# 1           1     C-35067     Jeannette Cha      F   57       1184.84
# 2           2     C-34590      Keva Godfrey      F   52       1266.27
# 3           3     C-16668      Elva Sackett      M   65       1369.72
# 4           4     C-12196    Sade Constable      F   60       1939.23
#
#   Income Stability            Profession Type of Employment    Location  ...  \
# 0              Low  Commercial associate           Managers  Semi-Urban  ...
# 1              Low               Working        Sales staff       Rural  ...
# 2              Low               Working                NaN  Semi-Urban  ...
# 3             High             Pensioner                NaN       Rural  ...
# 4             High             Pensioner                NaN       Urban  ...
#
#    Dependents Credit Score  No. of Defaults  Has Active Credit Card  \
# 0         2.0       799.14                0             Unpossessed
# 1         2.0       833.31                0             Unpossessed
# 2         3.0       627.44                0             Unpossessed
# 3         2.0       833.20                0                Inactive
# 4         NaN          NaN                0                     NaN
#
#    Property ID Property Age  Property Type  Property Location  Co-Applicant  \
# 0          843      3472.69              2              Urban             1
# 1           22      1184.84              1              Rural             1
# 2            1      1266.27              1              Urban             1
# 3          730      1369.72              1         Semi-Urban             0
# 4          356      1939.23              4         Semi-Urban             1
#
#   Property Price
# 0      236644.50
# 1      142357.30
# 2      300991.24
# 3      125612.10
# 4      180908.00
#
# [5 rows x 22 columns]

# %%
# Identifying null values

df.isnull()
# Out:
#    Unnamed: 0  Customer ID   Name  Gender    Age  Income (USD)  \
# 0       False        False  False   False  False         False
# 1       False        False  False   False  False         False
# 2       False        False  False   False  False         False
# 3       False        False  False   False  False         False
# 4       False        False  False   False  False         False
#
#    Income Stability  Profession  Type of Employment  Location  ...  \
# 0             False       False               False     False  ...
# 1             False       False               False     False  ...
# 2             False       False                True     False  ...
# 3             False       False                True     False  ...
# 4             False       False                True     False  ...
#
#    Dependents  Credit Score  No. of Defaults  Has Active Credit Card  \
# 0       False         False            False                   False
# 1       False         False            False                   False
# 2       False         False            False                   False
# 3       False         False            False                   False
# 4        True          True            False                    True
#
#    Property ID  Property Age  Property Type  Property Location  Co-Applicant  \
# 0        False         False          False              False         False
# 1        False         False          False              False         False
# 2        False         False          False              False         False
# 3        False         False          False              False         False
# 4        False         False          False              False         False
#
#    Property Price
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#
# [5 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# Customer ID                  0
# Name                         0
# Gender                       0
# Age                          0
# Income (USD)                 0
# Income Stability             0
# Profession                   0
# Type of Employment           3
# Location                     0
# Loan Amount Request (USD)    0
# ...                          0
# Dependents                   1
# Credit Score                 1
# No. of Defaults              0
# Has Active Credit Card       1
# Property ID                  0
# Property Age                 0
# Property Type                0
# Property Location            0
# Co-Applicant                 0
# Property Price               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 5 non-null      int64
#  1   Customer ID                5 non-null      object
#  2   Name                       5 non-null      object
#  3   Gender                     5 non-null      object
#  4   Age                        5 non-null      int64
#  5   Income (USD)               5 non-null      float64
#  6   Income Stability           5 non-null      object
#  7   Profession                 5 non-null      object
#  8   Type of Employment         2 non-null      object
#  9   Location                   5 non-null      object
#  10  Loan Amount Request (USD)  5 non-null      float64
#  11  ...                        5 non-null      object
#  12  Dependents                 4 non-null      float64
#  13  Credit Score               4 non-null      float64
#  14  No. of Defaults            5 non-null      int64
#  15  Has Active Credit Card     4 non-null      object
#  16  Property ID                5 non-null      int64
#  17  Property Age               5 non-null      float64
#  18  Property Type              5 non-null      int64
#  19  Property Location          5 non-null      object
#  20  Co-Applicant               5 non-null      int64
#  21  Property Price             5 non-null      float64
# dtypes: float64(6), int64(6), object(10)
# memory usage: 1012.0+ bytes

# %%
# let's see how we can implement this method
df2 = df["Dependents"].fillna(value = 0) # it will replace all null values with value 0.
df2.head()
#here this 0 acts as a indicator or a constant value which denotes thr programmer 
# the null exisitnce 0 is a good option due to its presence doesnt create redundancy


##LETS CHECK IF THERE IS ANY NULL VALUES PRESent
df2.isnull().sum()
# hence no null value are present
# Out:
# np.int64(0)

# %%
# Now let's try filling with value of the previous row
df3 = df.fillna(method='pad')
df3 #the output will have the Nan value replaced with the value of the row above it
# Out:
# C:\Users\Shivam Kumar\AppData\Local\Temp\ipykernel_15244\2970366813.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3 = df.fillna(method='pad')
#    Unnamed: 0 Customer ID              Name Gender  Age  Income (USD)  \
# 0           0     C-26247  Tandra Olszewski      F   47       3472.69
# 1           1     C-35067     Jeannette Cha      F   57       1184.84
# 2           2     C-34590      Keva Godfrey      F   52       1266.27
# 3           3     C-16668      Elva Sackett      M   65       1369.72
# 4           4     C-12196    Sade Constable      F   60       1939.23
#
#   Income Stability            Profession Type of Employment    Location  ...  \
# 0              Low  Commercial associate           Managers  Semi-Urban  ...
# 1              Low               Working        Sales staff       Rural  ...
# 2              Low               Working        Sales staff  Semi-Urban  ...
# 3             High             Pensioner        Sales staff       Rural  ...
# 4             High             Pensioner        Sales staff       Urban  ...
#
#    Dependents Credit Score  No. of Defaults  Has Active Credit Card  \
# 0         2.0       799.14                0             Unpossessed
# 1         2.0       833.31                0             Unpossessed
# 2         3.0       627.44                0             Unpossessed
# 3         2.0       833.20                0                Inactive
# 4         2.0       833.20                0                Inactive
#
#    Property ID Property Age  Property Type  Property Location  Co-Applicant  \
# 0          843      3472.69              2              Urban             1
# 1           22      1184.84              1              Rural             1
# 2            1      1266.27              1              Urban             1
# 3          730      1369.72              1         Semi-Urban             0
# 4          356      1939.23              4         Semi-Urban             1
#
#   Property Price
# 0      236644.50
# 1      142357.30
# 2      300991.24
# 3      125612.10
# 4      180908.00
#
# [5 rows x 22 columns]

# %%
df4 = df.fillna(method='bfill')
df4
# Out:
# C:\Users\Shivam Kumar\AppData\Local\Temp\ipykernel_15244\2773247164.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df4 = df.fillna(method='bfill')
#    Unnamed: 0 Customer ID              Name Gender  Age  Income (USD)  \
# 0           0     C-26247  Tandra Olszewski      F   47       3472.69
# 1           1     C-35067     Jeannette Cha      F   57       1184.84
# 2           2     C-34590      Keva Godfrey      F   52       1266.27
# 3           3     C-16668      Elva Sackett      M   65       1369.72
# 4           4     C-12196    Sade Constable      F   60       1939.23
#
#   Income Stability            Profession Type of Employment    Location  ...  \
# 0              Low  Commercial associate           Managers  Semi-Urban  ...
# 1              Low               Working        Sales staff       Rural  ...
# 2              Low               Working                NaN  Semi-Urban  ...
# 3             High             Pensioner                NaN       Rural  ...
# 4             High             Pensioner                NaN       Urban  ...
#
#    Dependents Credit Score  No. of Defaults  Has Active Credit Card  \
# 0         2.0       799.14                0             Unpossessed
# 1         2.0       833.31                0             Unpossessed
# 2         3.0       627.44                0             Unpossessed
# 3         2.0       833.20                0                Inactive
# 4         NaN          NaN                0                     NaN
#
#    Property ID Property Age  Property Type  Property Location  Co-Applicant  \
# 0          843      3472.69              2              Urban             1
# 1           22      1184.84              1              Rural             1
# 2            1      1266.27              1              Urban             1
# 3          730      1369.72              1         Semi-Urban             0
# 4          356      1939.23              4         Semi-Urban             1
#
#   Property Price
# 0      236644.50
# 1      142357.30
# 2      300991.24
# 3      125612.10
# 4      180908.00
#
# [5 rows x 22 columns]

# %%
# Filling null values with the previous value but column wise
df5 = df.fillna(method='pad',axis=1)
df5
# Out:
# C:\Users\Shivam Kumar\AppData\Local\Temp\ipykernel_15244\1035411179.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df5 = df.fillna(method='pad',axis=1)
#   Unnamed: 0 Customer ID              Name Gender Age Income (USD)  \
# 0          0     C-26247  Tandra Olszewski      F  47      3472.69
# 1          1     C-35067     Jeannette Cha      F  57      1184.84
# 2          2     C-34590      Keva Godfrey      F  52      1266.27
# 3          3     C-16668      Elva Sackett      M  65      1369.72
# 4          4     C-12196    Sade Constable      F  60      1939.23
#
#   Income Stability            Profession Type of Employment    Location  ...  \
# 0              Low  Commercial associate           Managers  Semi-Urban  ...
# 1              Low               Working        Sales staff       Rural  ...
# 2              Low               Working            Working  Semi-Urban  ...
# 3             High             Pensioner          Pensioner       Rural  ...
# 4             High             Pensioner          Pensioner       Urban  ...
#
#   Dependents Credit Score No. of Defaults Has Active Credit Card Property ID  \
# 0        2.0       799.14               0            Unpossessed         843
# 1        2.0       833.31               0            Unpossessed          22
# 2        3.0       627.44               0            Unpossessed           1
# 3        2.0        833.2               0               Inactive         730
# 4        ...          ...               0                      0         356
#
#   Property Age Property Type Property Location Co-Applicant Property Price
# 0      3472.69             2             Urban            1       236644.5
# 1      1184.84             1             Rural            1       142357.3
# 2      1266.27             1             Urban            1      300991.24
# 3      1369.72             1        Semi-Urban            0       125612.1
# 4      1939.23             4        Semi-Urban            1       180908.0
#
# [5 rows x 22 columns]

# %%
# Now let's fill different default null values column wise
df6 = df.fillna({'Type of Employment': 'Yet to ask', 'Dependents': '2.5'})#this is constant as we set that users hasent entered
df6
# Out:
#    Unnamed: 0 Customer ID              Name Gender  Age  Income (USD)  \
# 0           0     C-26247  Tandra Olszewski      F   47       3472.69
# 1           1     C-35067     Jeannette Cha      F   57       1184.84
# 2           2     C-34590      Keva Godfrey      F   52       1266.27
# 3           3     C-16668      Elva Sackett      M   65       1369.72
# 4           4     C-12196    Sade Constable      F   60       1939.23
#
#   Income Stability            Profession Type of Employment    Location  ...  \
# 0              Low  Commercial associate           Managers  Semi-Urban  ...
# 1              Low               Working        Sales staff       Rural  ...
# 2              Low               Working         Yet to ask  Semi-Urban  ...
# 3             High             Pensioner         Yet to ask       Rural  ...
# 4             High             Pensioner         Yet to ask       Urban  ...
#
#    Dependents Credit Score No. of Defaults  Has Active Credit Card  \
# 0         2.0       799.14               0             Unpossessed
# 1         2.0       833.31               0             Unpossessed
# 2         3.0       627.44               0             Unpossessed
# 3         2.0       833.20               0                Inactive
# 4         2.5          NaN               0                     NaN
#
#    Property ID Property Age  Property Type  Property Location  Co-Applicant  \
# 0          843      3472.69              2              Urban             1
# 1           22      1184.84              1              Rural             1
# 2            1      1266.27              1              Urban             1
# 3          730      1369.72              1         Semi-Urban             0
# 4          356      1939.23              4         Semi-Urban             1
#
#   Property Price
# 0      236644.50
# 1      142357.30
# 2      300991.24
# 3      125612.10
# 4      180908.00
#
# [5 rows x 22 columns]

# %%
plt.figure(figsize=(16, 8))  # Larger figure size

# Histogram
plt.subplot(1, 2, 1)
sns.histplot(df['Income (USD)'], kde=True)
plt.title('Histogram of Income (USD)')
plt.xlim(0, 10000)

# Density Plot (KDE)
plt.subplot(1, 2, 2)
sns.kdeplot(df['Income (USD)'], shade=True)
plt.title('Density Plot of Income (USD)')
plt.xlim(0, 10000)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Shivam Kumar\AppData\Local\Temp\ipykernel_15244\2101588368.py:11: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Income (USD)'], shade=True)

# %%
df['Income (USD)'].median()
# Out:
# np.float64(1369.72)

# %%
# now let's implement it
#filling null value with the mean of a column
df7 = df['Income (USD)'].fillna(value=df['Income (USD)'].median())
print(df7)
# Out:
# 0    3472.69
# 1    1184.84
# 2    1266.27
# 3    1369.72
# 4    1939.23
# Name: Income (USD), dtype: float64

# %%
# Create subplots with shared y-axis
fig, axs = plt.subplots(1, 3, figsize=(16, 6), sharey=True)  # 1 row, 3 columns

# Plot original data distribution
sns.histplot(df['Income (USD)'], kde=True, color='lightblue', bins=40, ax=axs[0])
axs[0].set_title("Original Data Distribution")
axs[0].set_xlabel("Income (USD)")
axs[0].set_ylabel("Frequency")
axs[0].set_xlim(0, 10000)  # Set x-axis limits for the first subplot

# Plot data distribution after filling with median
sns.histplot(df7, kde=True, color='green', bins=40, ax=axs[1])
axs[1].set_title("Data Distribution after Filling with Median")
axs[1].set_xlabel("Income (USD)")
axs[1].set_xlim(0, 10000)  # Set x-axis limits for the second subplot

# Ensure the third subplot has the same y-axis limits as the first two
plt.xlim(0, 10000)

plt.show()

# %%
# dropna()

#let's drop all the row with the null values in the dataset
df10 = df.dropna()
df10
# Out:
#    Unnamed: 0 Customer ID              Name Gender  Age  Income (USD)  \
# 0           0     C-26247  Tandra Olszewski      F   47       3472.69
# 1           1     C-35067     Jeannette Cha      F   57       1184.84
#
#   Income Stability            Profession Type of Employment    Location  ...  \
# 0              Low  Commercial associate           Managers  Semi-Urban  ...
# 1              Low               Working        Sales staff       Rural  ...
#
#    Dependents Credit Score  No. of Defaults  Has Active Credit Card  \
# 0         2.0       799.14                0             Unpossessed
# 1         2.0       833.31                0             Unpossessed
#
#    Property ID Property Age  Property Type  Property Location  Co-Applicant  \
# 0          843      3472.69              2              Urban             1
# 1           22      1184.84              1              Rural             1
#
#   Property Price
# 0       236644.5
# 1       142357.3
#
# [2 rows x 22 columns]

# %%
# Now let's see how does 'how' parameter work
# how='any' means if any row has a null values it is removed (default)
df11 =df.dropna(how='any')
df11
# Out:
#    Unnamed: 0 Customer ID              Name Gender  Age  Income (USD)  \
# 0           0     C-26247  Tandra Olszewski      F   47       3472.69
# 1           1     C-35067     Jeannette Cha      F   57       1184.84
#
#   Income Stability            Profession Type of Employment    Location  ...  \
# 0              Low  Commercial associate           Managers  Semi-Urban  ...
# 1              Low               Working        Sales staff       Rural  ...
#
#    Dependents Credit Score  No. of Defaults  Has Active Credit Card  \
# 0         2.0       799.14                0             Unpossessed
# 1         2.0       833.31                0             Unpossessed
#
#    Property ID Property Age  Property Type  Property Location  Co-Applicant  \
# 0          843      3472.69              2              Urban             1
# 1           22      1184.84              1              Rural             1
#
#   Property Price
# 0       236644.5
# 1       142357.3
#
# [2 rows x 22 columns]

# %%
# how='all' means it drop the row that have all nul values

df12 = df.dropna(how='all')
df12
# Out:
#    Unnamed: 0 Customer ID              Name Gender  Age  Income (USD)  \
# 0           0     C-26247  Tandra Olszewski      F   47       3472.69
# 1           1     C-35067     Jeannette Cha      F   57       1184.84
# 2           2     C-34590      Keva Godfrey      F   52       1266.27
# 3           3     C-16668      Elva Sackett      M   65       1369.72
# 4           4     C-12196    Sade Constable      F   60       1939.23
#
#   Income Stability            Profession Type of Employment    Location  ...  \
# 0              Low  Commercial associate           Managers  Semi-Urban  ...
# 1              Low               Working        Sales staff       Rural  ...
# 2              Low               Working                NaN  Semi-Urban  ...
# 3             High             Pensioner                NaN       Rural  ...
# 4             High             Pensioner                NaN       Urban  ...
#
#    Dependents Credit Score  No. of Defaults  Has Active Credit Card  \
# 0         2.0       799.14                0             Unpossessed
# 1         2.0       833.31                0             Unpossessed
# 2         3.0       627.44                0             Unpossessed
# 3         2.0       833.20                0                Inactive
# 4         NaN          NaN                0                     NaN
#
#    Property ID Property Age  Property Type  Property Location  Co-Applicant  \
# 0          843      3472.69              2              Urban             1
# 1           22      1184.84              1              Rural             1
# 2            1      1266.27              1              Urban             1
# 3          730      1369.72              1         Semi-Urban             0
# 4          356      1939.23              4         Semi-Urban             1
#
#   Property Price
# 0      236644.50
# 1      142357.30
# 2      300991.24
# 3      125612.10
# 4      180908.00
#
# [5 rows x 22 columns]

# %%
# What if you want to drop column with null values, there is a parameter for it

df13 = df.dropna(axis=1)
df13
# Out:
#    Unnamed: 0 Customer ID              Name Gender  Age  Income (USD)  \
# 0           0     C-26247  Tandra Olszewski      F   47       3472.69
# 1           1     C-35067     Jeannette Cha      F   57       1184.84
# 2           2     C-34590      Keva Godfrey      F   52       1266.27
# 3           3     C-16668      Elva Sackett      M   65       1369.72
# 4           4     C-12196    Sade Constable      F   60       1939.23
#
#   Income Stability            Profession    Location  \
# 0              Low  Commercial associate  Semi-Urban
# 1              Low               Working       Rural
# 2              Low               Working  Semi-Urban
# 3             High             Pensioner       Rural
# 4             High             Pensioner       Urban
#
#    Loan Amount Request (USD)  ...  No. of Defaults  Property ID  Property Age  \
# 0                  137088.98  ...                0          843       3472.69
# 1                  104771.59  ...                0           22       1184.84
# 2                  176684.91  ...                0            1       1266.27
# 3                   97009.18  ...                0          730       1369.72
# 4                  109980.00  ...                0          356       1939.23
#
#    Property Type Property Location  Co-Applicant  Property Price
# 0              2             Urban             1       236644.50
# 1              1             Rural             1       142357.30
# 2              1             Urban             1       300991.24
# 3              1        Semi-Urban             0       125612.10
# 4              4        Semi-Urban             1       180908.00

# %%
# Drop rows where specific columns have null values

df14 = df.dropna(subset=['Type of Employment', 'Dependents'])
df14
# Out:
#    Unnamed: 0 Customer ID              Name Gender  Age  Income (USD)  \
# 0           0     C-26247  Tandra Olszewski      F   47       3472.69
# 1           1     C-35067     Jeannette Cha      F   57       1184.84
#
#   Income Stability            Profession Type of Employment    Location  ...  \
# 0              Low  Commercial associate           Managers  Semi-Urban  ...
# 1              Low               Working        Sales staff       Rural  ...
#
#    Dependents Credit Score  No. of Defaults  Has Active Credit Card  \
# 0         2.0       799.14                0             Unpossessed
# 1         2.0       833.31                0             Unpossessed
#
#    Property ID Property Age  Property Type  Property Location  Co-Applicant  \
# 0          843      3472.69              2              Urban             1
# 1           22      1184.84              1              Rural             1
#
#   Property Price
# 0       236644.5
# 1       142357.3
#
# [2 rows x 22 columns]

# %%
# Drop rows with at least a certain number of non-null values

df15 =  df.dropna(thresh=5)
df15
# Out:
#    Unnamed: 0 Customer ID              Name Gender  Age  Income (USD)  \
# 0           0     C-26247  Tandra Olszewski      F   47       3472.69
# 1           1     C-35067     Jeannette Cha      F   57       1184.84
# 2           2     C-34590      Keva Godfrey      F   52       1266.27
# 3           3     C-16668      Elva Sackett      M   65       1369.72
# 4           4     C-12196    Sade Constable      F   60       1939.23
#
#   Income Stability            Profession Type of Employment    Location  ...  \
# 0              Low  Commercial associate           Managers  Semi-Urban  ...
# 1              Low               Working        Sales staff       Rural  ...
# 2              Low               Working                NaN  Semi-Urban  ...
# 3             High             Pensioner                NaN       Rural  ...
# 4             High             Pensioner                NaN       Urban  ...
#
#    Dependents Credit Score  No. of Defaults  Has Active Credit Card  \
# 0         2.0       799.14                0             Unpossessed
# 1         2.0       833.31                0             Unpossessed
# 2         3.0       627.44                0             Unpossessed
# 3         2.0       833.20                0                Inactive
# 4         NaN          NaN                0                     NaN
#
#    Property ID Property Age  Property Type  Property Location  Co-Applicant  \
# 0          843      3472.69              2              Urban             1
# 1           22      1184.84              1              Rural             1
# 2            1      1266.27              1              Urban             1
# 3          730      1369.72              1         Semi-Urban             0
# 4          356      1939.23              4         Semi-Urban             1
#
#   Property Price
# 0      236644.50
# 1      142357.30
# 2      300991.24
# 3      125612.10
# 4      180908.00
#
# [5 rows x 22 columns]

# %%
# Understanding Interpolation

# Create a copy of the DataFrame for demonstration
df_interpolated = df.copy()

# Interpolate missing values in the 'Income (USD)' column
df_interpolated['Income (USD)_interpolated'] = df['Income (USD)'].interpolate(method='linear')

# Plot histograms to compare distributions
plt.figure(figsize=(18, 8))

# Original data distribution
plt.subplot(1, 2, 1)
sns.histplot(df['Income (USD)'], kde=True, color='lightblue', bins=40)
plt.title('Original Data Distribution')
plt.xlabel('Income (USD)')
plt.ylabel('Frequency')
plt.xlim(0, 10000)  # Limit x-axis to focus on relevant income range

# Interpolated data distribution
plt.subplot(1, 2, 2)
sns.histplot(df_interpolated['Income (USD)_interpolated'], kde=True, color='green', bins=40)
plt.title('Data Distribution after Interpolation')
plt.xlabel('Income (USD)')
plt.ylabel('Frequency')
plt.xlim(0, 10000)  # Limit x-axis to focus on relevant income range

plt.tight_layout()
plt.show()

# %%
# Interpolate missing values using polynomial interpolation of degree 2
# Polynomial interpolation is useful when the relationship between the data points is non-linear

df17 = df.interpolate(method='polynomial', order=2)
df17
# Out:
# C:\Users\Shivam Kumar\AppData\Local\Temp\ipykernel_15244\3349519341.py:4: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df17 = df.interpolate(method='polynomial', order=2)
#    Unnamed: 0 Customer ID              Name Gender  Age  Income (USD)  \
# 0           0     C-26247  Tandra Olszewski      F   47       3472.69
# 1           1     C-35067     Jeannette Cha      F   57       1184.84
# 2           2     C-34590      Keva Godfrey      F   52       1266.27
# 3           3     C-16668      Elva Sackett      M   65       1369.72
# 4           4     C-12196    Sade Constable      F   60       1939.23
#
#   Income Stability            Profession Type of Employment    Location  ...  \
# 0              Low  Commercial associate           Managers  Semi-Urban  ...
# 1              Low               Working        Sales staff       Rural  ...
# 2              Low               Working                NaN  Semi-Urban  ...
# 3             High             Pensioner                NaN       Rural  ...
# 4             High             Pensioner                NaN       Urban  ...
#
#    Dependents Credit Score  No. of Defaults  Has Active Credit Card  \
# 0         2.0       799.14                0             Unpossessed
# 1         2.0       833.31                0             Unpossessed
# 2         3.0       627.44                0             Unpossessed
# 3         2.0       833.20                0                Inactive
# 4         NaN          NaN                0                     NaN
#
#    Property ID Property Age  Property Type  Property Location  Co-Applicant  \
# 0          843      3472.69              2              Urban             1
# 1           22      1184.84              1              Rural             1
# 2            1      1266.27              1              Urban             1
# 3          730      1369.72              1         Semi-Urban             0
# 4          356      1939.23              4         Semi-Urban             1
#
#   Property Price
# 0      236644.50
# 1      142357.30
# 2      300991.24
# 3      125612.10
# 4      180908.00
#
# [5 rows x 22 columns]

# %%
# Interpolate missing categorical values using the most recent non-null value

df19 = df.interpolate(method='pad')
df19
# Out:
# C:\Users\Shivam Kumar\AppData\Local\Temp\ipykernel_15244\1211071350.py:3: FutureWarning: DataFrame.interpolate with method=pad is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df19 = df.interpolate(method='pad')
#    Unnamed: 0 Customer ID              Name Gender  Age  Income (USD)  \
# 0           0     C-26247  Tandra Olszewski      F   47       3472.69
# 1           1     C-35067     Jeannette Cha      F   57       1184.84
# 2           2     C-34590      Keva Godfrey      F   52       1266.27
# 3           3     C-16668      Elva Sackett      M   65       1369.72
# 4           4     C-12196    Sade Constable      F   60       1939.23
#
#   Income Stability            Profession Type of Employment    Location  ...  \
# 0              Low  Commercial associate           Managers  Semi-Urban  ...
# 1              Low               Working        Sales staff       Rural  ...
# 2              Low               Working        Sales staff  Semi-Urban  ...
# 3             High             Pensioner        Sales staff       Rural  ...
# 4             High             Pensioner        Sales staff       Urban  ...
#
#    Dependents Credit Score  No. of Defaults  Has Active Credit Card  \
# 0         2.0       799.14                0             Unpossessed
# 1         2.0       833.31                0             Unpossessed
# 2         3.0       627.44                0             Unpossessed
# 3         2.0       833.20                0                Inactive
# 4         2.0       833.20                0                Inactive
#
#    Property ID Property Age  Property Type  Property Location  Co-Applicant  \
# 0          843      3472.69              2              Urban             1
# 1           22      1184.84              1              Rural             1
# 2            1      1266.27              1              Urban             1
# 3          730      1369.72              1         Semi-Urban             0
# 4          356      1939.23              4         Semi-Urban             1
#
#   Property Price
# 0      236644.50
# 1      142357.30
# 2      300991.24
# 3      125612.10
# 4      180908.00
#
# [5 rows x 22 columns]

# %%
# The replace() method

import numpy as np
df20 = df.replace(to_replace= np.nan, value= 0)
df20
# Out:
#    Unnamed: 0 Customer ID              Name Gender  Age  Income (USD)  \
# 0           0     C-26247  Tandra Olszewski      F   47       3472.69
# 1           1     C-35067     Jeannette Cha      F   57       1184.84
# 2           2     C-34590      Keva Godfrey      F   52       1266.27
# 3           3     C-16668      Elva Sackett      M   65       1369.72
# 4           4     C-12196    Sade Constable      F   60       1939.23
#
#   Income Stability            Profession Type of Employment    Location  ...  \
# 0              Low  Commercial associate           Managers  Semi-Urban  ...
# 1              Low               Working        Sales staff       Rural  ...
# 2              Low               Working                  0  Semi-Urban  ...
# 3             High             Pensioner                  0       Rural  ...
# 4             High             Pensioner                  0       Urban  ...
#
#    Dependents Credit Score  No. of Defaults  Has Active Credit Card  \
# 0         2.0       799.14                0             Unpossessed
# 1         2.0       833.31                0             Unpossessed
# 2         3.0       627.44                0             Unpossessed
# 3         2.0       833.20                0                Inactive
# 4         0.0         0.00                0                       0
#
#    Property ID Property Age  Property Type  Property Location  Co-Applicant  \
# 0          843      3472.69              2              Urban             1
# 1           22      1184.84              1              Rural             1
# 2            1      1266.27              1              Urban             1
# 3          730      1369.72              1         Semi-Urban             0
# 4          356      1939.23              4         Semi-Urban             1
#
#   Property Price
# 0      236644.50
# 1      142357.30
# 2      300991.24
# 3      125612.10
# 4      180908.00
#
# [5 rows x 22 columns]

# %%
# End of Distribution
# Before Imputation

# Calculate quartiles
q1 = df['Age'].quantile(0.25)  # First quartile (25th percentile)
q2 = df['Age'].quantile(0.5)   # Second quartile (median)
q3 = df['Age'].quantile(0.75)  # Third quartile (75th percentile)

print("First Quartile (Q1):", q1)
print("Median (Q2):", q2)
print("Third Quartile (Q3):", q3)

# Create a box plot to visualize skewness
sns.boxplot(x=df['Age'])
plt.title('Box Plot for Age')
plt.show()
# Out:
# First Quartile (Q1): 52.0
# Median (Q2): 57.0
# Third Quartile (Q3): 60.0

# %%
q1 = df['Age'].quantile(0.25)
q3 = df['Age'].quantile(0.75)
iqr = q3 - q1  # Interquartile Range

# lower and upper whiskers
lower_whisker = q1 - 1.5 * iqr
upper_whisker = q3 + 1.5 * iqr

print("Lower Whisker:", lower_whisker)
print("Upper Whisker:", upper_whisker)
# Out:
# Lower Whisker: 40.0
# Upper Whisker: 72.0

# %%
# Fill NaN with lower and upper whiskers
# Assuming one want to use these whiskers for imputation
df_lower_filled = df.fillna(lower_whisker)  # Fill with lower whisker
df_upper_filled = df.fillna(upper_whisker)  # Fill with upper whisker

# Display the results
print("Original DataFrame:")
df
# Out:
# Original DataFrame:
#    Unnamed: 0 Customer ID              Name Gender  Age  Income (USD)  \
# 0           0     C-26247  Tandra Olszewski      F   47       3472.69
# 1           1     C-35067     Jeannette Cha      F   57       1184.84
# 2           2     C-34590      Keva Godfrey      F   52       1266.27
# 3           3     C-16668      Elva Sackett      M   65       1369.72
# 4           4     C-12196    Sade Constable      F   60       1939.23
#
#   Income Stability            Profession Type of Employment    Location  ...  \
# 0              Low  Commercial associate           Managers  Semi-Urban  ...
# 1              Low               Working        Sales staff       Rural  ...
# 2              Low               Working                NaN  Semi-Urban  ...
# 3             High             Pensioner                NaN       Rural  ...
# 4             High             Pensioner                NaN       Urban  ...
#
#    Dependents Credit Score  No. of Defaults  Has Active Credit Card  \
# 0         2.0       799.14                0             Unpossessed
# 1         2.0       833.31                0             Unpossessed
# 2         3.0       627.44                0             Unpossessed
# 3         2.0       833.20                0                Inactive
# 4         NaN          NaN                0                     NaN
#
#    Property ID Property Age  Property Type  Property Location  Co-Applicant  \
# 0          843      3472.69              2              Urban             1
# 1           22      1184.84              1              Rural             1
# 2            1      1266.27              1              Urban             1
# 3          730      1369.72              1         Semi-Urban             0
# 4          356      1939.23              4         Semi-Urban             1
#
#   Property Price
# 0      236644.50
# 1      142357.30
# 2      300991.24
# 3      125612.10
# 4      180908.00
#
# [5 rows x 22 columns]

# %%
#BEFORE
# Calculate quartiles and visualize original distribution
q1 = df['Age'].quantile(0.25)  # First quartile (25th percentile)
q2 = df['Age'].quantile(0.5)   # Second quartile (median)
q3 = df['Age'].quantile(0.75)  # Third quartile (75th percentile)

print("First Quartile (Q1):", q1)
print("Median (Q2):", q2)
print("Third Quartile (Q3):", q3)

# Create a histogram to visualize original distribution
plt.figure(figsize=(10, 6))
plt.hist(df['Age'], bins=30, color='lightblue', edgecolor='black')
plt.axvline(x=q1, color='red', linestyle='--', label='Q1 (25th percentile)')
plt.axvline(x=q2, color='green', linestyle='--', label='Q2 (50th percentile)')
plt.axvline(x=q3, color='blue', linestyle='--', label='Q3 (75th percentile)')
plt.title('Histogram of Age - Original Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# First Quartile (Q1): 52.0
# Median (Q2): 57.0
# Third Quartile (Q3): 60.0

# %%
#AFTER
# Determine lower and upper whiskers for outlier detection
iqr = q3 - q1  # Interquartile Range
lower_whisker = q1 - 1.5 * iqr
upper_whisker = q3 + 1.5 * iqr

print("Lower Whisker:", lower_whisker)
print("Upper Whisker:", upper_whisker)

# Fill NaN values with lower and upper whiskers
df_lower_filled = df.fillna(lower_whisker)  # Fill with lower whisker
df_upper_filled = df.fillna(upper_whisker)  # Fill with upper whisker

# Create histograms to visualize the filled distributions
plt.figure(figsize=(14, 6))

# Histogram after filling with lower whisker
plt.subplot(1, 2, 1)
plt.hist(df_lower_filled['Age'], bins=30, color='orange', edgecolor='black')
plt.axvline(x=lower_whisker, color='red', linestyle='--', label='Lower Whisker')
plt.title('Histogram of Age - Filled with Lower Whisker')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)

# Histogram after filling with upper whisker
plt.subplot(1, 2, 2)
plt.hist(df_upper_filled['Age'], bins=30, color='green', edgecolor='black')
plt.axvline(x=upper_whisker, color='blue', linestyle='--', label='Upper Whisker')
plt.title('Histogram of Age - Filled with Upper Whisker')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Lower Whisker: 40.0
# Upper Whisker: 72.0

# %%
# KNN IMPUTATION

# Assuming df is your loan dataset loaded properly

# Select columns for KNN imputation
columns_for_knn = ['Income (USD)', 'Credit Score', 'Property Age']

# Visualize histograms before imputation
plt.figure(figsize=(14, 10))
for i, col in enumerate(columns_for_knn, 1):
    plt.subplot(3, 2, i)
    plt.hist(df[col].dropna(), bins=30, color='blue', edgecolor='black')
    plt.title(f'Histogram of {col} - Before Imputation')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
from sklearn.impute import KNNImputer

# Perform KNN imputation
imputer = KNNImputer(n_neighbors=5)
df_knn_imputed = pd.DataFrame(imputer.fit_transform(df[columns_for_knn]), columns=columns_for_knn)

# Visualize histograms after imputation
plt.figure(figsize=(14, 10))
for i, col in enumerate(columns_for_knn, 1):
    plt.subplot(3, 2, i)
    plt.hist(df_knn_imputed[col], bins=30, color='green', edgecolor='black')
    plt.title(f'Histogram of {col} - After KNN Imputation')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# MICE (Multiple Imputation by Chained Equations)

# Visualize histograms before imputation (assuming df is your loan dataset)
plt.figure(figsize=(14, 10))
for i, col in enumerate(columns_for_knn, 1):
    plt.subplot(3, 2, i)
    plt.hist(df[col].dropna(), bins=30, color='blue', edgecolor='black')
    plt.title(f'Histogram of {col} - Before Imputation')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# Perform MICE imputation
imputer_mice = IterativeImputer(random_state=0)
df_mice_imputed = pd.DataFrame(imputer_mice.fit_transform(df[columns_for_knn]), columns=columns_for_knn)

# Visualize histograms after imputation
plt.figure(figsize=(14, 10))
for i, col in enumerate(columns_for_knn, 1):
    plt.subplot(3, 2, i)
    plt.hist(df_mice_imputed[col], bins=30, color='orange', edgecolor='black')
    plt.title(f'Histogram of {col} - After MICE Imputation')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(True)

plt.tight_layout()
plt.show()
